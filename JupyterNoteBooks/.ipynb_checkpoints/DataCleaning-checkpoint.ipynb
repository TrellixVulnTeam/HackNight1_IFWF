# %%
import pandas as pd
from sklearn import preprocessing
from datetime import datetime

# %%
train=pd.read_csv("trainms.csv")
train.
trainY=train['treatment']
trainX=train.drop(['treatment'],axis=1)
testX=pd.read_csv("testms.csv")

# %%
train.head()
# Out:
#    s.no            Timestamp  Age  Gender         Country state self_employed  \
# 0     1  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     3  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     4  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     5  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere  ...               leave  \
# 0             No       Yes          Often  ...       Somewhat easy
# 1             No        No         Rarely  ...          Don't know
# 2             No        No         Rarely  ...  Somewhat difficult
# 3            Yes       Yes          Often  ...  Somewhat difficult
# 4             No        No          Never  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# 0                        No                      No  Some of them        Yes
# 1                     Maybe                      No            No         No
# 2                        No                      No           Yes        Yes
# 3                       Yes                     Yes  Some of them         No
# 4                        No                      No  Some of them        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
#
#   obs_consequence comments
# 0              No      NaN
# 1              No      NaN
# 2              No      NaN
# 3             Yes      NaN
# 4              No      NaN
#
# [5 rows x 28 columns]

# %%
trainX.head()
trainY.head()
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4124ddb20ab8> in <module>
#       1 trainX.head()
#       2 trainY.head()
# ----> 3 test.head()
#
# NameError: name 'test' is not defined

# %%
trainX['family_history'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Data Cleaning

# %%
def replace_for(col,k1,k2):
    trainX[col]=trainX[col].replace(k1,k2)

# %%
male=['Male','male','m','maile','Cis Male','Mal','Male ','Man','msle','Mail','cis male','Make']
replace_for('Gender',male,"M")

# %%
female=['Female','female','Cis Female','Woman','F','f','Femake','woman','Female ','cis-female/femme','Female (cis)']
replace_for('Gender',female,"F")

# %%
other=list(trainX['Gender'].unique())
other.remove('F')
other.remove('M')
replace_for('Gender',other,'O')

# %%
trainX['Gender'].unique()
# Out:
# array(['F', 'M', 'O'], dtype=object)

# %%
kill=list(trainX.columns)

# %%
date_format=[]
day=[]
date=[]
for i in train['Timestamp']:
    kill=datetime.strptime(i, "%Y-%m-%d %H:%M:%S")
    date_format.append(kill)
    day.append(kill.weekday())
    date.append(kill.day)

# %%
train['weekday']=pd.Series(day)
train['date']=pd.Series(date)

# %% [markdown]
# ## correleation matrix

# %%
train.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                                s.no  Timestamp       Age    Gender   Country  \
# s.no                       1.000000   0.999993  0.071188  0.068771  0.082711
# Timestamp                  0.999993   1.000000  0.071036  0.068737  0.082438
# Age                        0.071188   0.071036  1.000000  0.074700  0.083682
# mental_health_interview   -0.072786      -0.108150       -0.101058   0.112458
# phys_health_interview      0.015088       0.013804        0.054501  -0.085100
# mental_vs_physical        -0.033395       0.077546        0.092236  -0.053456
# obs_consequence           -0.074370      -0.052231        0.151283  -0.181406
# comments                   0.024639      -0.012610        0.087134  -0.048775
#
#                            work_interfere  ...     leave  \
# s.no                            -0.014850  ...  0.053050
# Timestamp                       -0.014926  ...  0.053090
# Age                             -0.022970  ... -0.006436
# Gender                           0.035410  ...  0.029599
# Country                         -0.046070  ...  0.048592
# state                            0.026060  ... -0.013050
# self_employed                   -0.060295  ... -0.081253
# family_history                   0.186014  ...  0.017973
# treatment                       -0.414327  ... -0.055430
# work_interfere                   1.000000  ...  0.027939
# no_employees                     0.046082  ...  0.037281
# remote_work                     -0.014061  ...  0.131853
# tech_company                    -0.014862  ... -0.001500
# benefits                        -0.039740  ...  0.055960
# care_options                     0.082484  ...  0.066727
# wellness_program                 0.045894  ...  0.003925
# seek_help                       -0.029477  ...  0.045619
# anonymity                        0.016456  ... -0.052272
# leave                            0.027939  ...  1.000000
# mental_health_consequence        0.158263  ... -0.021909
# phys_health_consequence          0.086499  ... -0.045265
# coworkers                       -0.035946  ...  0.107401
# supervisor                       0.092070  ... -0.076357
# mental_health_interview         -0.091355  ...  0.026722
# phys_health_interview           -0.004415  ... -0.005790
# mental_vs_physical               0.060990  ... -0.080324
# obs_consequence                  0.077833  ...  0.067755
# comments                         0.075906  ...  0.072331
#
#                            mental_health_consequence  phys_health_consequence  \
# s.no                                        0.048244                 0.075025
# Timestamp                                   0.048053                 0.074803
# Age                                         0.013088                 0.024642
# Gender                                      0.066939                 0.073661
# Country                                     0.019234                 0.035918
# state                                       0.002564                -0.009814
# self_employed                               0.071291                 0.017433
# family_history                              0.136097                 0.061072
# treatment                                  -0.180130                -0.059991
# work_interfere                              0.158263                 0.086499
# no_employees                                0.022719                 0.017295
# remote_work                                -0.005534                 0.028331
# tech_company                                0.115947                 0.066725
# benefits                                    0.064080                 0.079079
# care_options                                0.031858                -0.010175
# wellness_program                           -0.137207                -0.057681
# seek_help                                   0.137296                 0.078944
# anonymity                                   0.246826                 0.139899
# leave                                      -0.021909                -0.045265
# mental_health_consequence                   1.000000                 0.465860
# phys_health_consequence                     0.465860                 1.000000
# coworkers                                  -0.123837                -0.047311
# supervisor                                  0.334358                 0.243504
# mental_health_interview                    -0.310909                -0.104494
# phys_health_interview                      -0.063651                -0.082331
# mental_vs_physical                          0.448103                 0.229727
# obs_consequence                             0.251418                 0.148363
# comments                                    0.023050                 0.008470
#
#                            coworkers  supervisor  mental_health_interview  \
# s.no                       -0.031112    0.024676                -0.063030
# Timestamp                  -0.031059    0.024433                -0.062850
# Age                         0.010137   -0.011149                -0.025969
# Gender                      0.021667    0.083310                -0.017315
# Country                     0.009418    0.003284                 0.121534
# state                       0.006976   -0.047075                -0.072786
# self_employed              -0.081408    0.056515                -0.108150
# family_history              0.005344    0.009697                -0.101058
# treatment                  -0.020475   -0.041072                 0.112458
# work_interfere             -0.035946    0.092070                -0.091355
# no_employees               -0.017390    0.021543                -0.017474
# remote_work                 0.069485   -0.079353                 0.073544
# tech_company               -0.013436    0.043003                -0.073089
# benefits                    0.040945    0.032218                 0.030853
# care_options                0.012297   -0.043237                 0.002058
# wellness_program           -0.019667   -0.053136                 0.016497
# seek_help                   0.038893    0.048394                -0.004034
# anonymity                  -0.027839    0.129482                -0.086444
# leave                       0.107401   -0.076357                 0.026722
# mental_health_consequence  -0.123837    0.334358                -0.310909
# phys_health_consequence    -0.047311    0.243504                -0.104494
# coworkers                   1.000000   -0.277775                 0.129882
# supervisor                 -0.277775    1.000000                -0.201915
# mental_health_interview     0.129882   -0.201915                 1.000000
# phys_health_interview       0.062598   -0.038298                -0.029328
# mental_vs_physical         -0.105552    0.191582                -0.202177
# obs_consequence            -0.067515    0.119402                -0.079962
# comments                    0.022456   -0.010325                 0.014422
#
#                            phys_health_interview  mental_vs_physical  \
# s.no                                   -0.016091           -0.005446
# Timestamp                              -0.016020           -0.005375
# Age                                    -0.011284            0.019536
# Gender                                  0.002904           -0.022613
# Country                                 0.066181            0.041234
# state                                   0.015088           -0.033395
# self_employed                           0.013804            0.077546
# family_history                          0.054501            0.092236
# treatment                              -0.085100           -0.053456
# work_interfere                         -0.004415            0.060990
# no_employees                            0.007907           -0.024752
# remote_work                            -0.026858           -0.085193
# tech_company                            0.019838            0.119875
# benefits                               -0.024900            0.114701
# care_options                            0.024343           -0.023956
# wellness_program                        0.033722           -0.264470
# seek_help                              -0.001575            0.257696
# anonymity                              -0.031866            0.267596
# leave                                  -0.005790           -0.080324
# mental_health_consequence              -0.063651            0.448103
# phys_health_consequence                -0.082331            0.229727
# coworkers                               0.062598           -0.105552
# supervisor                             -0.038298            0.191582
# mental_health_interview                -0.029328           -0.202177
# phys_health_interview                   1.000000           -0.031310
# mental_vs_physical                     -0.031310            1.000000
# obs_consequence                         0.014253            0.262269
# comments                               -0.032707           -0.032384
#
#                            obs_consequence  comments
# s.no                              0.070649  0.184491
# Timestamp                         0.070658  0.184391
# Age                               0.086821  0.024735
# Gender                            0.067662  0.078484
# Country                           0.096067  0.013708
# state                            -0.074370  0.024639
# self_employed                    -0.052231 -0.012610
# family_history                    0.151283  0.087134
# treatment                        -0.181406 -0.048775
# work_interfere                    0.077833  0.075906
# no_employees                      0.053275  0.089840
# remote_work                      -0.012704  0.039881
# tech_company                      0.055807  0.017357
# benefits                          0.031025  0.000989
# care_options                      0.068337  0.003047
# wellness_program                  0.027713  0.056284
# seek_help                         0.024600 -0.043689
# anonymity                         0.060959 -0.066792
# leave                             0.067755  0.072331
# mental_health_consequence         0.251418  0.023050
# phys_health_consequence           0.148363  0.008470
# coworkers                        -0.067515  0.022456
# supervisor                        0.119402 -0.010325
# mental_health_interview          -0.079962  0.014422
# phys_health_interview             0.014253 -0.032707
# mental_vs_physical                0.262269 -0.032384
# obs_consequence                   1.000000  0.067549
# comments                          0.067549  1.000000
#
# [28 rows x 28 columns]
